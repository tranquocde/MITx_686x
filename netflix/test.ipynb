# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import numpy as np
import kmeans
import common
import naive_em
import em

X = np.loadtxt("toy_data.txt")

# TODO: Your code here
for K in range(1,5):
    mixture , post = common.init(X,K,seed=0)
    mixture , post , ll = naive_em.run(X,mixture,post)
    bic_score = common.bic(X,mixture , ll)

    print(f"bic_score for K = {K} : {bic_score}")
    common.plot(X,mixture,post,title=f"figure for K = {K}")
# Out:
# bic_score for K = 1 : -1315.5056231368872
# bic_score for K = 2 : -1195.0397982183192
# bic_score for K = 3 : -1169.2589347355097
# bic_score for K = 4 : -1180.108825003948

# %%
import numpy as np
x = np.array([[1,1],[2,2]])
sum(x[1])
# Out:
# 4
